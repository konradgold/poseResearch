# %%
from ultralytics import YOLO

model = YOLO("yolo11n-pose.pt")

# %%
import cv2
path = "/Volumes/KG1TB/data/Untitled.mov"
video = cv2.VideoCapture(path)

# %%
while video.isOpened():
    ret, img = video.read()
    break

# %%
from matplotlib import pyplot as plt
img = img[..., ::-1]
plt.imshow(img)

# %%
r = model("/Volumes/KG1TB/data/Untitled.mov", stream=True, )

# %%
for result in r:
    print(result)
    break
# Out:
# video 1/1 (frame 1/1801) /Volumes/KG1TB/data/Untitled.mov: 480x640 3 persons, 50.2ms
# ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: ultralytics.engine.results.Keypoints object
# masks: None
# names: {0: 'person'}
# obb: None
# orig_img: array([[[  1,   4,   1],
#         [  1,   4,   1],
#         [  1,   4,   1],
#         ...,
#         [105, 101,  88],
#         [104, 100,  87],
#         [104, 100,  87]],
#
#        [[  1,   4,   1],
#         [  1,   4,   1],
#         [  1,   4,   1],
#         ...,
#         [100,  95,  82],
#         [ 96,  91,  79],
#         [ 94,  89,  76]],
#
#        [[  1,   4,   1],
#         [  1,   4,   1],
#         [  1,   4,   1],
#         ...,
#         [ 77,  75,  63],
#         [ 75,  73,  61],
#         [ 74,  72,  60]],
#
#        ...,
#
#        [[140, 141, 139],
#         [141, 143, 140],
#         [141, 143, 140],
#         ...,
#         [  1,   4,   1],
# ...

# %%
from pose_validation import PoseValidation

pv, cosine_matrix = PoseValidation.pose_keypoint_similarity(result.keypoints, 
                                             result.keypoints.data)

# %%
print(pv)
# Out:
# 0.9505494435628256

# %%
print(cosine_matrix)
# Out:
# [[          1     0.99639     0.61666]
#  [         -0     0.92857          -0]
#  [         -0          -0     0.92308]]

# %%
img_with_poses = r[0].plot()

#cv2.imshow("YOLO Pose", img_with_poses[..., ::-1])

# %%
r[0].keypoints[0].data[0,13,1]
# Out:
# tensor(0.)
